# %% [markdown]
# 1.
# =

# %% [markdown]
# See Pledge.md in main repo.

# %% [markdown]
# 2.
# =

# %% [markdown]
# A.
# -

# %%
theta = arange(-pi,pi+0.1,0.1)
y = (cos(2*theta)*cos(theta/2))**2
plot(theta,y)
xlabel(r"$\theta$(rad)", fontsize = 14)          #making my x-axis label and sizing the font
ylabel('Intensity', fontsize = 14)           #making my y-axis label and sizing the font
title(r"Intensity vs $\theta$")                   #creating the appropriate title and adding the legend in the correct spot
legend( loc = "upper right")
xticks(np.arange(-pi, pi, pi/4),("$-\pi$", "$-3\pi/4$", "$-\pi/2$", "$-\pi/4$", "0.0","$\pi/4$", "$\pi/2$", "$-3\pi/4$", "$\pi$"))
grid()
show()

# %% [markdown]
# B.
# -

# %%
t = arange(-5,5.1,0.1)
y = e**(-t)
z = (1+t)/(t-1)
plot(t,y, color='red', linestyle='--', label='exp(-t)')
axis([-5,5,-10,10])
plot(t,z, color='blue', label='(1+t)/(t-1)')
axis([-5,5,-10,10])
ylabel('f(t), g(t)', fontsize = 14)
xlabel('time(seconds)', fontsize = 14)
ax.annotate("discontinuous here", xy = (1, -1), xytext = (1, -1)) #I'm not sure why but this doesnt work
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-c07655af2268> in <module>()
#       8 ylabel('f(t), g(t)', fontsize = 14)
#       9 xlabel('time(seconds)', fontsize = 14)
# ---> 10 ax.annotate("discontinuous here", xy = (1, -1), xytext = (1, -1)) #I'm not sure why but this doesnt work
#      11 show()
#
# NameError: name 'ax' is not defined

# %% [markdown]
# 3.
# =

# %% [markdown]
# A.
# -

# %% [markdown]
# See Electrostatics.py for pointField function

# %% [markdown]
# B.
# -

# %%
from newEl import *
a = 1
b = 2
density = 1e-6
Xq = 3
Yq = 3
x,y = meshgrid(arange(-5,5,0.5),arange(-5,5,0.5))
pointField(x,y,3e-6,3,3)        #if it won't even notice that I don't have a pointField function (which I have) there's no way
                                # i can integrate it
#integrate.quad(pointField(x,y,3e-6,3,3),-Inf,Inf)
# Out:
#   File "<ipython-input-70-607191410c88>", line 8
#     pointField(x,y,3e-6,3,3))
#                             ^
# SyntaxError: invalid syntax

# %% [markdown]
# C.
# -

# %% [markdown]
# 3.
# =

# %% [markdown]
# A.
# -

# %%
#prefixes = [J,K,L,M,N,O,P,Q]
prefixes = 'JKLMNOPQ'
suffix = 'ack'
other_suffix = 'uack'

for letter in prefixes:
    if letter == O: # also tried str(letter) == str(O), str(letter) == 'O', 
        print letter + other_suffix
    elif letter == Q:
        print letter + other_suffix
    else:
        print letter + suffix
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-64fdde99699a> in <module>()
#       5
#       6 for letter in prefixes:
# ----> 7     if str(letter) == str(O): # also tried str(letter) == str(O), str(letter) == 'O',
#       8         print letter + other_suffix
#       9     elif letter == Q:
#
# NameError: name 'O' is not defined

# %% [markdown]
# B.
# -

# %%
def is_anagram(s1, s2):
    """We want to find how to find words that are anagrams of eachother"""
    if len(s1) != len(s2):
        return "Will never be anagrams!"
    if len(s1) == len(s2):
        for a, b in zip(s1, s2):
            if a == b:
                
            
    return
